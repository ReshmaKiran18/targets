# %%
import tensorflow as tf
import numpy as np

# %%
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):

    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):

        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers
model=models.Sequential()
model.add(layers.Dense(64,activation='relu',input_shape=(10000,)))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(46,activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 2s 60ms/step - loss: 2.7156 - categorical_accuracy: 0.4053 - val_loss: 1.8316 - val_categorical_accuracy: 0.6125
# Epoch 2/25
# 16/16 [==============================] - 1s 34ms/step - loss: 1.5812 - categorical_accuracy: 0.6728 - val_loss: 1.3836 - val_categorical_accuracy: 0.6975
# Epoch 3/25
# 16/16 [==============================] - 0s 27ms/step - loss: 1.2384 - categorical_accuracy: 0.7338 - val_loss: 1.2093 - val_categorical_accuracy: 0.7275
# Epoch 4/25
# 16/16 [==============================] - 0s 27ms/step - loss: 1.0167 - categorical_accuracy: 0.7802 - val_loss: 1.0944 - val_categorical_accuracy: 0.7525
# Epoch 5/25
# 16/16 [==============================] - 0s 26ms/step - loss: 0.8476 - categorical_accuracy: 0.8189 - val_loss: 1.0101 - val_categorical_accuracy: 0.7763
# Epoch 6/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.7069 - categorical_accuracy: 0.8489 - val_loss: 0.9478 - val_categorical_accuracy: 0.8025
# Epoch 7/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.5905 - categorical_accuracy: 0.8723 - val_loss: 0.9128 - val_categorical_accuracy: 0.8075
# Epoch 8/25
# 16/16 [==============================] - 0s 26ms/step - loss: 0.4921 - categorical_accuracy: 0.8966 - val_loss: 0.8814 - val_categorical_accuracy: 0.8075
# Epoch 9/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.4180 - categorical_accuracy: 0.9118 - val_loss: 0.8855 - val_categorical_accuracy: 0.8050
# Epoch 10/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.3570 - categorical_accuracy: 0.9248 - val_loss: 0.8809 - val_categorical_accuracy: 0.7975
# Epoch 11/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.3028 - categorical_accuracy: 0.9361 - val_loss: 0.8691 - val_categorical_accuracy: 0.8138
# Epoch 12/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2638 - categorical_accuracy: 0.9405 - val_loss: 0.8873 - val_categorical_accuracy: 0.8125
# Epoch 13/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2349 - categorical_accuracy: 0.9434 - val_loss: 0.8866 - val_categorical_accuracy: 0.8062
# Epoch 14/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.2068 - categorical_accuracy: 0.9490 - val_loss: 0.9008 - val_categorical_accuracy: 0.8138
# Epoch 15/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1902 - categorical_accuracy: 0.9518 - val_loss: 0.9329 - val_categorical_accuracy: 0.8012
# Epoch 16/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1771 - categorical_accuracy: 0.9521 - val_loss: 0.9385 - val_categorical_accuracy: 0.8012
# Epoch 17/25
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1601 - categorical_accuracy: 0.9554 - val_loss: 0.9691 - val_categorical_accuracy: 0.7962
# Epoch 18/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1531 - categorical_accuracy: 0.9555 - val_loss: 0.9787 - val_categorical_accuracy: 0.8075
# Epoch 19/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1425 - categorical_accuracy: 0.9545 - val_loss: 0.9626 - val_categorical_accuracy: 0.8075
# Epoch 20/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1399 - categorical_accuracy: 0.9569 - val_loss: 0.9811 - val_categorical_accuracy: 0.8000
# Epoch 21/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1297 - categorical_accuracy: 0.9575 - val_loss: 0.9920 - val_categorical_accuracy: 0.8037
# Epoch 22/25
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1239 - categorical_accuracy: 0.9580 - val_loss: 1.0476 - val_categorical_accuracy: 0.7962
# Epoch 23/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1240 - categorical_accuracy: 0.9575 - val_loss: 1.0277 - val_categorical_accuracy: 0.7950
# Epoch 24/25
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1181 - categorical_accuracy: 0.9576 - val_loss: 1.0511 - val_categorical_accuracy: 0.7962
# Epoch 25/25
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1185 - categorical_accuracy: 0.9598 - val_loss: 1.0244 - val_categorical_accuracy: 0.7950

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
