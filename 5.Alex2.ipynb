# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPool2D, BatchNormalization, Dropout
from keras.layers import Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator

# %%
model = Sequential()

model.add(Conv2D(input_shape=[224,224,3], filters=64,kernel_size=[3,3], padding='same', activation='relu'))
model.add(Conv2D(filters=64,kernel_size=[3,3], padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=[2,2], strides=[2,2]))

model.add(Conv2D(filters=64,kernel_size=[3,3], padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=64,kernel_size=[3,3], padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(MaxPool2D(pool_size=[2,2], strides=[2,2]))

model.add(Conv2D(filters=128,kernel_size=[3,3], padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(filters=128,kernel_size=[3,3], padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(filters=128,kernel_size=[3,3], padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(MaxPool2D(pool_size=[2,2], strides=[2,2]))

model.add(Conv2D(filters=256,kernel_size=[3,3], padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(filters=256,kernel_size=[3,3], padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(filters=256,kernel_size=[3,3], padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=[2,2], strides=[2,2]))

model.add(Conv2D(filters=512,kernel_size=[3,3], padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(filters=512,kernel_size=[3,3], padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(filters=512,kernel_size=[3,3], padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(MaxPool2D(pool_size=[2,2], strides=[2,2]))

model.add(Flatten())
model.add(Dense(units=4096,activation='relu'))
model.add(BatchNormalization())

model.add(Dense(units=4096,activation='relu'))
model.add(BatchNormalization())


model.add(Dense(units=38, activation="softmax"))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 224, 224, 64)      1792
#
#  conv2d_12 (Conv2D)          (None, 224, 224, 64)      36928
#
#  max_pooling2d_4 (MaxPoolin  (None, 112, 112, 64)      0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 112, 112, 64)      36928
#
#  batch_normalization_8 (Bat  (None, 112, 112, 64)      256
#  chNormalization)
#
#  conv2d_14 (Conv2D)          (None, 112, 112, 64)      36928
#
#  batch_normalization_9 (Bat  (None, 112, 112, 64)      256
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 56, 56, 64)        0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 56, 56, 128)       73856
#
#  batch_normalization_10 (Ba  (None, 56, 56, 128)       512
#  tchNormalization)
#
#  conv2d_16 (Conv2D)          (None, 56, 56, 128)       147584
#
#  batch_normalization_11 (Ba  (None, 56, 56, 128)       512
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 56, 56, 128)       147584
#
#  batch_normalization_12 (Ba  (None, 56, 56, 128)       512
#  tchNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 28, 28, 128)       0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 28, 28, 256)       295168
#
#  batch_normalization_13 (Ba  (None, 28, 28, 256)       1024
#  tchNormalization)
#
#  conv2d_19 (Conv2D)          (None, 28, 28, 256)       590080
#
#  batch_normalization_14 (Ba  (None, 28, 28, 256)       1024
#  tchNormalization)
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 256)       590080
#
#  max_pooling2d_7 (MaxPoolin  (None, 14, 14, 256)       0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 14, 14, 512)       1180160
#
#  batch_normalization_15 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  batch_normalization_16 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  batch_normalization_17 (Ba  (None, 14, 14, 512)       2048
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 7, 7, 512)         0
#  g2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4096)              102764544
#
#  batch_normalization_18 (Ba  (None, 4096)              16384
#  tchNormalization)
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  batch_normalization_19 (Ba  (None, 4096)              16384
#  tchNormalization)
#
#  dense_2 (Dense)             (None, 38)                155686
#
# =================================================================
# Total params: 127601254 (486.76 MB)
# Trainable params: 127579750 (486.68 MB)
# Non-trainable params: 21504 (84.00 KB)
# _________________________________________________________________

# %%
from keras.optimizers import Adam
adam=Adam(learning_rate=0.001)

# %%
model.compile(optimizer=adam, loss=['categorical_crossentropy'],metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
cd //content/alexnet-plant-disease-classification.ipynb/'New Plant Diseases Dataset(Augmented)'/'New Plant Diseases Dataset(Augmented)'/
# Out:
# [Errno 2] No such file or directory: '//content/alexnet-plant-disease-classification.ipynb/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/'
# /content
